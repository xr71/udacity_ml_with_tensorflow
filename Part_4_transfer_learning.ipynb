# %%
import tensorflow as tf

# %%
import tensorflow_hub as hub

# %%
import tensorflow_datasets as tfds

# %%
import matplotlib.pyplot as plt

# %%
train_split = 60
test_val_split = 20

(training_set, validation_set, test_set), dataset_info = tfds.load('cats_vs_dogs', split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'], as_supervised=True, with_info=True)

# %%
# ?tfds.percent
# Out:
# Init signature: tfds.percent()
# Docstring:
# Syntactic sugar for defining slice subsplits: `tfds.percent[75:-5]`.
#
# See the
# [guide on splits](https://github.com/tensorflow/datasets/tree/master/docs/splits.md)
# for more information.
# File:           c:\users\music\miniconda3\lib\site-packages\tensorflow_datasets\core\splits.py
# Type:           PercentSliceMeta
# Subclasses:

# %%
training_set
# Out:
# <DatasetV1Adapter shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %%
for i, l in training_set.take(1):
    label = l.numpy()
    image = i.numpy()

# %%
plt.imshow(image)
